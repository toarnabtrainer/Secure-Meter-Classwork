# %% [markdown]
# <h1 style="color:brown" align="center"> <b>Numpy - Numeric Python </b></h1>

# %% [markdown]
# **NumPy** is an extennsion to the Python programming language, adding support for large, multi-dimensional (numerical) arrays and matrics, along with a large library of high-level mathematical functions to operate on those arrays. The full form of NumPy is Numeric Python.

# %% [markdown]
# ## **Section-1**

# %% [markdown]
# ## **Create Arrays**

# %% [markdown]
# ## **Examining Arrays**

# %% [markdown]
# ## **Create Special Array**

# %% [markdown]
# ## **Reshape**

# %% [markdown]
# ## **Append, Insert, Delete, and Sort**

# %% [markdown]
# ## <b>Concatenation and Stack of Two Arrays</b>

# %% [markdown]
# ## **Section-2**

# %% [markdown]
# ## **Selection**

# %% [markdown]
# ### Class Assignment-1
# > Create one nd-array with dimension 6x6 filled up with 0's only the border rows and border columns are filled up with 1's

# %% [markdown]
# ## **Views and Copies**

# %% [markdown]
# ## **Using Boolean Arrays**

# %% [markdown]
# ## **Vector Operations**

# %% [markdown]
# ## **Broadcasting**

# %% [markdown]
# ![image.png](attachment:1581620c-684f-4edb-84b5-08b9256f3e0b.png)
